# %%
# %load_ext rmagic
import rpy2 as Rpy

# %%
# %%R
# library(rjson)
# #make a list of business data
# business= "/Users/Work/Documents/CS246_Proj/yelp_phoenix_academic_dataset 2/yelp_academic_dataset_business.json"
# raw_biz= scan(business, what="raw()", sep="\n")
# #to make it human readable
# biz_data= lapply(raw_biz, function(x) fromJSON(x))
# #this how one JSON object looks like (list of lists)
# print( biz_data[[1]])
# #15585 businesses
# Out:
# Read 15585 items
# $business_id
# [1] "O_X3PGhk3Y5JWVi866qlJg"
#
# $full_address
# [1] "1501 W Bell Rd\nPhoenix, AZ 85023"
#
# $hours
# $hours$Monday
# $hours$Monday$close
# [1] "18:00"
#
# $hours$Monday$open
# [1] "11:00"
#
#
# $hours$Tuesday
# $hours$Tuesday$close
# [1] "18:00"
#
# $hours$Tuesday$open
# [1] "11:00"
#
#
# $hours$Friday
# $hours$Friday$close
# [1] "18:00"
#
# $hours$Friday$open
# [1] "11:00"
#
#
# $hours$Wednesday
# $hours$Wednesday$close
# [1] "18:00"
#
# $hours$Wednesday$open
# [1] "11:00"
#
#
# $hours$Thursday
# $hours$Thursday$close
# [1] "18:00"
#
# $hours$Thursday$open
# [1] "11:00"
#
#
# $hours$Sunday
# $hours$Sunday$close
# [1] "18:00"
#
# $hours$Sunday$open
# [1] "11:00"
#
#
# $hours$Saturday
# $hours$Saturday$close
# [1] "18:00"
#
# $hours$Saturday$open
# [1] "11:00"
#
#
#
# $open
# [1] TRUE
#
# $categories
# [1] "Active Life"          "Arts & Entertainment" "Stadiums & Arenas"
# [4] "Horse Racing"
#
# $city
# [1] "Phoenix"
#
# $review_count
# [1] 29
#
# $name
# [1] "Turf Paradise Race Course"
#
# $neighborhoods
# list()
#
# $longitude
# [1] -112.0923
#
# $state
# [1] "AZ"
#
# $stars
# [1] 4
#
# $latitude
# [1] 33.63857
#
# $attributes
# $attributes$`Take-out`
# [1] FALSE
#
# $attributes$`Wi-Fi`
# [1] "free"
#
# $attributes$`Good For`
# $attributes$`Good For`$dessert
# [1] FALSE
#
# $attributes$`Good For`$latenight
# [1] FALSE
#
# $attributes$`Good For`$lunch
# [1] FALSE
#
# $attributes$`Good For`$dinner
# [1] FALSE
#
# $attributes$`Good For`$brunch
# [1] FALSE
#
# $attributes$`Good For`$breakfast
# [1] FALSE
#
#
# $attributes$`Noise Level`
# [1] "average"
#
# $attributes$`Takes Reservations`
# [1] TRUE
#
# $attributes$`Has TV`
# [1] TRUE
#
# $attributes$Delivery
# [1] FALSE
#
# $attributes$Ambience
# $attributes$Ambience$romantic
# [1] FALSE
#
# $attributes$Ambience$intimate
# [1] FALSE
#
# $attributes$Ambience$touristy
# [1] FALSE
#
# $attributes$Ambience$hipster
# [1] FALSE
#
# $attributes$Ambience$divey
# [1] FALSE
#
# $attributes$Ambience$classy
# [1] FALSE
#
# $attributes$Ambience$trendy
# [1] FALSE
#
# $attributes$Ambience$upscale
# [1] FALSE
#
# $attributes$Ambience$casual
# [1] FALSE
#
#
# $attributes$Parking
# $attributes$Parking$garage
# [1] FALSE
#
# $attributes$Parking$street
# [1] FALSE
#
# $attributes$Parking$validated
# [1] FALSE
#
# $attributes$Parking$lot
# [1] TRUE
#
# $attributes$Parking$valet
# [1] TRUE
#
#
# $attributes$`Wheelchair Accessible`
# [1] TRUE
#
# $attributes$`Outdoor Seating`
# [1] TRUE
#
# $attributes$Attire
# [1] "casual"
#
# $attributes$Alcohol
# [1] "full_bar"
#
# $attributes$`Waiter Service`
# [1] TRUE
#
# $attributes$`Accepts Credit Cards`
# [1] TRUE
#
# $attributes$`Good for Kids`
# [1] FALSE
#
# $attributes$`Good For Groups`
# [1] TRUE
#
# $attributes$`Price Range`
# [1] 2
#
#
# $type
# [1] "business"

# %%
# %%R
# #make a list of user data
# user= "/Users/Work/Documents/CS246_Proj/yelp_phoenix_academic_dataset 2/yelp_academic_dataset_user.json"
# raw_user= scan(user, what="raw()", sep="\n")
# user_data= lapply(raw_user, function(x) fromJSON(x))
# #this how one JSON object looks like (list of lists)
# print ( user_data[[1]] )
# #70817 users
# Out:
# Read 70817 items
# $yelping_since
# [1] "2011-08"
#
# $votes
# $votes$funny
# [1] 0
#
# $votes$useful
# [1] 1
#
# $votes$cool
# [1] 1
#
#
# $review_count
# [1] 5
#
# $name
# [1] "Glen"
#
# $user_id
# [1] "HzLh-2WyMjf6TYATFwg6NA"
#
# $friends
# list()
#
# $fans
# [1] 0
#
# $average_stars
# [1] 3.6
#
# $type
# [1] "user"
#
# $compliments
# list()
#
# $elite
# list()

# %%
# %%R
# #make a list of review data
# review= "/Users/Work/Documents/CS246_Proj/yelp_phoenix_academic_dataset 2/yelp_academic_dataset_review.json"
# raw_review= scan(review, what="raw()", sep="\n")
# review_data= lapply(raw_review, function(x) fromJSON(x))
# #this how one JSON object looks like (list of lists)
# print ( review_data[[1]] )
# #335022 reviews
# Out:
# Read 335022 items
# $votes
# $votes$funny
# [1] 1
#
# $votes$useful
# [1] 1
#
# $votes$cool
# [1] 1
#
#
# $user_id
# [1] "r-t7IiTSD0QZdt8lOUCqeQ"
#
# $review_id
# [1] "0ESSqLfOae77muWTv_zUqA"
#
# $stars
# [1] 3
#
# $date
# [1] "2011-02-11"
#
# $text
# [1] "Lately i have been feeling homesick for asian food and been hitting up places that i haven't been to in awhile.  Recently re-visited Thai Pan for a quick lunch and quickly ordered without spending too much time perusing the menu.  It looked more diverse than I remembered including some Vietnamese additions.  I remembered the curries and stir-fry dishes were ok but nothing really memorable.  A quick summary for my latest visit:\n\nPros:\n- convenient order-at-the counter setup\n- self-serve drink station\n- brown and white rice mixture\n- friendly and gracious owners\n\nCons:\n- too much napa cabbage in comparison to green vegetables \n- wish the owner/chef would be back in the kitchen vs. managing\n- spice level on the weak side"
#
# $type
# [1] "review"
#
# $business_id
# [1] "WIcDFpHEnC3ihNmS7-6-ZA"

# %%
# %%R
# #playing with data
# #making lists for user data
# user.avg_stars = unlist(lapply(user_data, function(x) x$average_stars))
# user.id = unlist(lapply(user_data, function(x) x$user_id))
# user.join_date= unlist(lapply(user_data, function(x) x$yelping_since))
# user.join_date= paste(user.join_date, "-01", sep='')
# user.join_date= as.Date(user.join_date)
# user.review_count=unlist(lapply(user_data, function(x) x$review_count))
# user.vote_funny= unlist(lapply(user_data, function(x) x$votes$funny))
# user.vote_cool= unlist(lapply(user_data, function(x) x$votes$cool))
# user.vote_useful= unlist(lapply(user_data, function(x) x$votes$useful))
# user.fans= unlist(lapply(user_data, function(x) x$fans))
#
# #making a data frame from user lists
# user_table= data.frame(user.id, user.join_date, user.avg_stars, user.review_count, user.vote_funny,
# 	user.vote_cool, user.vote_useful, user.fans)
# colnames(user_table)=c("userId", "joinDate", "avgStars", "reviewCount", "voteFunny", "voteCool", "voteUseful", "fans")
#
# print ( head(user_table) )
# print ( summary(user_table) )
# Out:
#                   userId   joinDate avgStars reviewCount voteFunny voteCool
# 1 HzLh-2WyMjf6TYATFwg6NA 2011-08-01     3.60           5         0        1
# 2 gYV6bmTSgbZMGkvXHVCowg 2011-06-01     2.20           5        78        1
# 3 4duCDxDMiRJJbc2CmnziAg 2010-10-01     3.57           7         1        1
# 4 2EeuYhLuzvvrJ9v2pVrTjQ 2012-02-01     3.00           4         0        1
# 5 5AwX3A1D-PJkkrWuRpmpCA 2010-07-01     4.30          19         4        9
# 6 EAKOI5JjZU7rZU2FtoSoEA 2012-05-01     3.50           2         1        0
#   voteUseful fans
# 1          1    0
# 2          7    0
# 3          0    0
# 4          0    0
# 5         23    1
# 6          0    0
#                     userId         joinDate             avgStars
#  __6ThELn9arOmEfa4vqR2Q:    1   Min.   :2004-10-01   Min.   :0.000
#  __7iSC6XCyWW4pHd8Cz0SQ:    1   1st Qu.:2010-03-01   1st Qu.:3.290
#  __8Qi30fRr3gByvffDBlRg:    1   Median :2011-05-01   Median :3.880
#  __b7YV2PZCin-nL2KC4RKg:    1   Mean   :2011-03-08   Mean   :3.737
#  __FXEOrWIjXMOElz2pGlBQ:    1   3rd Qu.:2012-07-01   3rd Qu.:4.500
#  __i-_pFLWJJTO8mc7c5kBw:    1   Max.   :2014-01-01   Max.   :5.000
#  (Other)               :70811
#   reviewCount       voteFunny           voteCool          voteUseful
#  Min.   :   1.0   Min.   :    0.00   Min.   :    0.00   Min.   :    0.00
#  1st Qu.:   2.0   1st Qu.:    0.00   1st Qu.:    0.00   1st Qu.:    1.00
#  Median :   6.0   Median :    1.00   Median :    1.00   Median :    5.00
#  Mean   :  33.7   Mean   :   35.94   Mean   :   41.75   Mean   :   67.22
#  3rd Qu.:  18.0   3rd Qu.:    5.00   3rd Qu.:    6.00   3rd Qu.:   19.00
#  Max.   :3286.0   Max.   :25159.00   Max.   :23835.00   Max.   :27320.00
#
#       fans
#  Min.   :   0.000
#  1st Qu.:   0.000
#  Median :   0.000
#  Mean   :   1.619
#  3rd Qu.:   0.000
#  Max.   :1172.000

# %%
# %%R
# #plotting histograms
# par( mfrow=c(2,2))
# hist(user.avg_stars, main="Histogram of Average Star Ratings", xlab="Average Stars", col="darkcyan", border="white", lwd="2")
# hist(user.review_count, main="Histogram of Review Counts", xlab="Review Counts", col="orange", border="white", lwd="2")
# hist(user.fans, main="Histogram of Fans", xlab="Fans", col="grey", border="white", lwd="2")
# hist(user.join_date, "months", main="Histogram of Joining Yelp", xlab="Join Date",lwd="2", format = "%d %b")

# %%
# %%R
# #making lists for business data
# biz_id= unlist(lapply(biz_data, function(x) x$business_id))
# biz_long= unlist(lapply(biz_data, function(x) x$longitude))
# biz_lat= unlist(lapply(biz_data, function(x) x$latitude))
# biz_category=list(); for(i in 1:15585){ biz_category[[i]]=biz_data[[i]]$categories}
#
# library(maps)
# #map('state', plot = TRUE, fill = FALSE, col = palette())
# colors()[grep("green",colors())]
# map('county', 'Arizona', plot = TRUE, fill = TRUE, col="springgreen3"  , bg="white", ylim= c(min(biz_lat), max(biz_lat)),
# 	xlim= c(min(biz_long), max(biz_long)))
# title("Businesses in Yelp in Phoenix")
# points(x=biz_long, y=biz_lat, col="yellow", pch=20)
# map.axes()
